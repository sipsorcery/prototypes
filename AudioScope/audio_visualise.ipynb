# %%
#import sys
#!{sys.executable} -m pip install librosa matplotlib numpy scipy

import librosa
file_path = "simplicity.wav"
audio_samples, audio_sampling_rate = librosa.load(file_path, sr = None, mono = True, offset = 0.0, duration = None)
len(audio_samples), audio_sampling_rate

#duration = len(audio_samples) / audio_sampling_rate
#print(duration, " seconds")

#from IPython.display import Audio
#Audio(file_path)

from librosa import display
import matplotlib.pyplot as plt
import numpy as np
import scipy

# Plot time domain samples of audio recording.
#plt.figure()
#librosa.display.waveplot(y = samples, sr = sampling_rate)
#plt.xlabel("Time (seconds) -->")
#plt.ylabel("Amplitude")
#plt.show()

# Plot a sine wave.
num_samples = 100
x = np.arange(num_samples)
yl_3 = 2 * np.sin(2*np.pi*3 * (x/num_samples))
yl_11 = 2 * np.sin(2*np.pi*11 * (x/num_samples))
yl_sum = yl_3 + yl_11
#plt.figure(figsize=(20,10))
plt.figure()
#plt.stem(x,yl, 'r', use_line_collection=True)
plt.plot(x,yl_sum)
plt.xlabel("Time -->")
plt.ylabel("<-- Amplitude -->")
plt.show()

#print(yl)

def fft_plot(signal, sampling_rate):
    n = len(signal)
    T = 1/sampling_rate
    yf = scipy.fft.fft(signal)
    print(yf)
    xf = np.linspace(0.0, sampling_rate/2.0, n//2)
    #print(xf)
    fig, ax = plt.subplots()
    ax.plot(xf, 2.0/n * np.abs(yf[:n//2]))
    plt.grid()
    plt.xlabel("Frequency -->")
    plt.ylabel("Magnitude")
    return plt.show()

fft_plot(yl_sum, num_samples)
#fft_plot(audio_samples, audio_sampling_rate)
# Out:
# [ 1.20126131e-13-0.00000000e+00j -1.57183536e-14+5.56355309e-14j
#   2.36033163e-14+1.14265205e-14j -4.61419834e-14-1.00000000e+02j
#  -1.27484729e-14-1.44630201e-14j -8.11253020e-15-4.32223498e-15j
#  -2.43825868e-14+1.78479468e-14j  3.29664279e-14+3.43985690e-14j
#  -2.25701075e-14+1.88550536e-14j  1.17917831e-14+8.32191969e-14j
#  -2.62181258e-14+1.56927041e-13j -4.48164448e-13-1.00000000e+02j
#  -2.04248473e-14-1.79651437e-13j  5.88329743e-15-1.06894527e-13j
#   1.36883306e-14-5.86197757e-14j  2.68443208e-15-5.74337694e-14j
#   5.11112346e-15-3.71836974e-14j -6.76861406e-15-2.90876650e-14j
#  -2.71834779e-14-1.58084740e-14j  1.03772279e-14-1.03892972e-13j
#   4.15288071e-14-3.33370704e-14j -8.19507929e-15-3.67649127e-14j
#   6.84330328e-14-2.75335310e-14j -6.76090352e-15+2.30339255e-14j
#  -6.12950577e-15-3.54389046e-14j  1.33226763e-14-2.46469511e-14j
#   4.32286024e-14-2.68928042e-14j  1.09194809e-14-2.51163292e-15j
#  -3.81483776e-14-6.21724894e-15j  2.77052453e-14-3.06305731e-14j
