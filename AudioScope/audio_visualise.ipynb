# %%
#import sys
#!{sys.executable} -m pip install librosa matplotlib numpy scipy

import librosa
file_path = "simplicity.wav"
audio_samples, audio_sampling_rate = librosa.load(file_path, sr = None, mono = True, offset = 0.0, duration = None)
len(audio_samples), audio_sampling_rate

#duration = len(audio_samples) / audio_sampling_rate
#print(duration, " seconds")

#from IPython.display import Audio
#Audio(file_path)

from librosa import display
import matplotlib.pyplot as plt
import numpy as np
import scipy

# Plot time domain samples of audio recording.
#plt.figure()
#librosa.display.waveplot(y = samples, sr = sampling_rate)
#plt.xlabel("Time (seconds) -->")
#plt.ylabel("Amplitude")
#plt.show()

# Plot a sine wave.
num_samples = 100
x = np.arange(num_samples)
yl_3 = 2 * np.sin(2*np.pi*3 * (x/num_samples))
yl_11 = 2 * np.sin(2*np.pi*11 * (x/num_samples))
yl_sum = yl_3 + yl_11
#plt.figure(figsize=(20,10))
plt.figure()
#plt.stem(x,yl, 'r', use_line_collection=True)
plt.plot(x,yl_sum)
plt.xlabel("Time -->")
plt.ylabel("<-- Amplitude -->")
plt.show()

#print(yl)

def fft_plot(signal, sampling_rate):
    n = len(signal)
    T = 1/sampling_rate
    yf = scipy.fft.fft(signal)
    print(len(yf))
    xf = np.linspace(-sampling_rate/2.0, sampling_rate/2.0, n)
    #print(xf)
    for x,y in zip(xf, yf):
        print(x , ": " ,y, "\n")
    fig, ax = plt.subplots()
    ax.plot(xf, 2.0/n * np.abs(yf[:n//2]))
    plt.grid()
    plt.xlabel("Frequency -->")
    plt.ylabel("Magnitude")
    return plt.show()

fft_plot(yl_sum, num_samples)
#fft_plot(audio_samples, audio_sampling_rate)
# Out:
# 100
# -50.0 :  (1.2012613126444194e-13-0j)
#
# -48.98989898989899 :  (-1.5718353648473724e-14+5.563553087024975e-14j)
#
# -47.97979797979798 :  (2.3603316300291936e-14+1.14265204857793e-14j)
#
# -46.96969696969697 :  (-4.614198335241886e-14-99.99999999999993j)
#
# -45.95959595959596 :  (-1.2748472931312672e-14-1.4463020087871053e-14j)
#
# -44.94949494949495 :  (-8.112530201808454e-15-4.322234984658306e-15j)
#
# -43.93939393939394 :  (-2.438258684793612e-14+1.7847946782333774e-14j)
#
# -42.92929292929293 :  (3.296642789963862e-14+3.439856899881685e-14j)
#
# -41.91919191919192 :  (-2.2570107478954698e-14+1.885505361339975e-14j)
#
# -40.90909090909091 :  (1.1791783134941842e-14+8.321919692507997e-14j)
#
# -39.898989898989896 :  (-2.621812575063817e-14+1.569270407627204e-13j)
#
# -38.888888888888886 :  (-4.481644476068506e-13-100.00000000000003j)
#
# -37.878787878787875 :  (-2.0424847261939157e-14-1.7965143672695882e-13j)
#
# -36.868686868686865 :  (5.8832974346141236e-15-1.0689452689868461e-13j)
#
# -35.858585858585855 :  (1.3688330637214514e-14-5.861977570020827e-14j)
#
# -34.848484848484844 :  (2.684432082520849e-15-5.743376942334859e-14j)
#
# -33.838383838383834 :  (5.111123460653719e-15-3.7183697399472204e-14j)
#
# -32.82828282828282 :  (-6.768614056027842e-15-2.908766495058146e-14j)
#
# -31.818181818181817 :  (-2.718347791390197e-14-1.580847395772591e-14j)
#
# -30.808080808080806 :  (1.0377227908447302e-14-1.0389297164367093e-13j)
#
# -29.797979797979796 :  (4.152880712530962e-14-3.333707036994152e-14j)
#
# -28.787878787878785 :  (-8.19507929027885e-15-3.6764912659382046e-14j)
#
# -27.777777777777775 :  (6.84330327888973e-14-2.7533531010703882e-14j)
#
# 16.66666666666667 :  (-2.6772325965981806e-14+3.108520706031606e-14j)
#
# 17.676767676767682 :  (4.0779686154193224e-14-3.188969718930918e-15j)
#
# 18.686868686868692 :  (1.4361073898080027e-14+1.1421482133782055e-14j)
#
# 19.696969696969703 :  (1.005931270433611e-14+2.853243603518198e-15j)
#
# 20.707070707070713 :  (2.40531908526191e-14+3.861836640165625e-14j)
#
# 21.717171717171723 :  (2.7705245343675442e-14+3.063057306211826e-14j)
#
# 22.727272727272734 :  (-3.814837757511773e-14+6.217248937900877e-15j)
#
# 23.737373737373744 :  (1.0919480854234428e-14+2.5116329194267723e-15j)
#
# 24.747474747474755 :  (4.322860242805382e-14+2.6892804216425737e-14j)
#
# 25.757575757575765 :  (1.3322676295501878e-14+2.4646951146678475e-14j)
#
# 26.767676767676775 :  (-6.129505767906941e-15+3.5438904638728975e-14j)
#
# 27.777777777777786 :  (-6.760903517461451e-15-2.3033925477412985e-14j)
#
# 28.787878787878796 :  (6.84330327888973e-14+2.7533531010703882e-14j)
#
# 29.797979797979806 :  (-8.19507929027885e-15+3.6764912659382046e-14j)
#
# 30.808080808080817 :  (4.152880712530962e-14+3.333707036994152e-14j)
#
# 31.818181818181827 :  (1.0377227908447302e-14+1.0389297164367093e-13j)
#
# 32.82828282828284 :  (-2.718347791390197e-14+1.580847395772591e-14j)
#
# 33.83838383838385 :  (-6.768614056027842e-15+2.908766495058146e-14j)
#
# 34.84848484848486 :  (5.111123460653719e-15+3.7183697399472204e-14j)
#
# 35.85858585858587 :  (2.684432082520849e-15+5.743376942334859e-14j)
#
# 36.86868686868688 :  (1.3688330637214514e-14+5.861977570020827e-14j)
#
# 37.87878787878789 :  (5.8832974346141236e-15+1.0689452689868461e-13j)
#
# 38.8888888888889 :  (-2.0424847261939157e-14+1.7965143672695882e-13j)
#
# 39.89898989898991 :  (-4.481644476068506e-13+100.00000000000003j)
#
# 40.90909090909092 :  (-2.621812575063817e-14-1.569270407627204e-13j)
#
# 41.91919191919193 :  (1.1791783134941842e-14-8.321919692507997e-14j)
#
# 42.92929292929294 :  (-2.2570107478954698e-14-1.885505361339975e-14j)
#
# 43.93939393939395 :  (3.296642789963862e-14-3.439856899881685e-14j)
#
# 44.94949494949496 :  (-2.438258684793612e-14-1.7847946782333774e-14j)
#
# 45.95959595959597 :  (-8.112530201808454e-15+4.322234984658306e-15j)
#
# 46.96969696969697 :  (-1.2748472931312672e-14+1.4463020087871053e-14j)
#
# 47.97979797979798 :  (-4.614198335241886e-14+99.99999999999993j)
#
# 48.98989898989899 :  (2.3603316300291936e-14-1.14265204857793e-14j)
#
# 50.0 :  (-1.5718353648473724e-14-5.563553087024975e-14j)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-881b2f949e32> in <module>
#      57     return plt.show()
#      58
# ---> 59 fft_plot(yl_sum, num_samples)
#      60 #fft_plot(audio_samples, audio_sampling_rate)
#
# <ipython-input-76-881b2f949e32> in fft_plot(signal, sampling_rate)
#      51         print(x , ": " ,y, "\n")
#      52     fig, ax = plt.subplots()
# ---> 53     ax.plot(xf, 2.0/n * np.abs(yf[:n//2]))
#      54     plt.grid()
#      55     plt.xlabel("Frequency -->")
#
# c:\users\aaron\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1644         """
#    1645         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1646         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1647         for line in lines:
#    1648             self.add_line(line)
#
# c:\users\aaron\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# c:\users\aaron\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (100,) and (50,)
